# %%
import pandas as pd

# %%
identity = pd.read_excel("../data/인격.xlsx").set_index("id").sort_index()
ego = pd.read_excel("../data/에고.xlsx",dtype=str).set_index("id").sort_index()

# %%
identity = identity.replace('참격',1).replace('관통',2).replace('타격',3)\
                             .replace('분노',1).replace('색욕',2).replace('나태',3).replace('탐식',4).replace('우울',5).replace('오만',6).replace('질투',7)\
                             .replace('보유',0).replace('공명',1)
identity
# Out:
#        sinner      identity grade  min_speed  max_speed  hp_coeffic  hp_const  \
# id
# 01I001     이상       LCB 수감자     ∅          4          8        2.48      72.0
# 01I002     이상   남부 세븐 협회 6과    ∅∅          5          8        2.82      82.0
# 01I003     이상         검계 살수   ∅∅∅          3          7        2.28      66.0
# 01I004     이상  개화 E.G.O::동백   ∅∅∅          3          7        2.28      66.0
# 01I005     이상   어금니 사무소 해결사    ∅∅          4          7        2.50      73.0
# ...       ...           ...   ...        ...        ...         ...       ...
# 12I005   그레고르  장미스패너 공방 해결사    ∅∅          4          6        2.39      69.0
# 12I006   그레고르  남부 츠바이 협회 4과   ∅∅∅          4          8        3.05      88.0
# 12I007   그레고르  쌍갈고리 해적단 부선장   ∅∅∅          3          7        2.28      66.0
# 12I008   그레고르       흑운회 부조장    ∅∅          4          6        2.60      76.0
# 12I009   그레고르    에드가 가문 승계자   ∅∅∅          3          8        2.28      66.0
#
#         atk1Lv  atk2Lv  atk3Lv  ...  Discard  battlePassive_sin  \
# id                              ...
# 01I001     0.0     0.0     0.0  ...      0.0                  5
# 01I002     0.0     0.0     0.0  ...      0.0                  4
# 01I003     5.0     5.0     5.0  ...      0.0                  6
# 01I004     4.0     3.0     5.0  ...      0.0                  3
# 01I005    -2.0     2.0     5.0  ...      0.0                  3
# ...        ...     ...     ...  ...      ...                ...
# 12I005     1.0     1.0     1.0  ...      0.0                  4
# 12I006     0.0     0.0     0.0  ...      0.0                  3
# 12I007     2.0     3.0     5.0  ...      0.0                  6
# 12I008     1.0     2.0     2.0  ...      0.0                  2
# 12I009     5.0     5.0     5.0  ...      0.0                  5
#
#         battlePassive_sinCnt  battlePassive_type  \
# id
# 01I001                     4                   1
# 01I002                     4                   1
# 01I003                     4                   0
# 01I004                     4                   0
# 01I005                     3                   0
# ...                      ...                 ...
# 12I005                     4                   0
# 12I006                     5                   0
# 12I007                     2                   0
# 12I008                     4                   0
# 12I009                     3                   1
#
#                                             battlePassive  supportPassive_sin  \
# id
# 01I001              조작 패널에서 자신의 뒤에 있는 아군 2명에게 피해량 증가 1 부여                   5
# 01I002                                 합 진행 시 대상의 합 위력 -2                   4
# 01I003                                  합 승리 시 호흡 횟수 1 증가                   6
# 01I004                              2명 이상을 공격할 때 피해량 +30%                   3
# 01I005  적에게 진동 폭발 시 입히는 흐트러짐 손상 4 당 방어 레벨 감소 1 부여 (턴마다...                   3
# ...                                                   ...                 ...
# 12I005                             진동이 있는 대상에게 부여하는 파열 +1                   4
# 12I006  전투 시작 시 자신이 2개 이상의 스킬의 타겟이 되었다면 방어 레벨 증가 2 얻음....                   3
# 12I007  출혈이 부여된 대상에게 앞면 적중 시 부당 수익을 얻음(최대 4). 탄환을 소모하는...                   6
# 12I008                            합 승리 시 출혈 1 부여 (턴 당 3회)                   2
# 12I009  전투 시작 시 이전 턴 시작 시와의 정신력 차이 5당 피해량 증가 1, 취약 1 얻...                   5
#
#         supportPassive_sinCnt  supportPassive_type  \
# id
# 01I001                      4                    0
# 01I002                      3                    1
# 01I003                      3                    0
# 01I004                      3                    1
# 01I005                      3                    0
# ...                       ...                  ...
# 12I005                      4                    0
# 12I006                      5                    0
# 12I007                      4                    0
# 12I008                      4                    0
# 12I009                      3                    0
#
#                                            supportPassive  etc
# id
# 01I001  정신력이 가장 낮은 아군 1명 이번 턴에 정신력이 감소한 경우 턴 종료 시 정신력 ...  NaN
# 01I002                         최대 체력이 가장 높은 아군 1명 합 위력 +1  NaN
# 01I003                정신력이 가장 높은 아군 1명 스킬 효과로 얻는 호흡 횟수 +1  NaN
# 01I004            정신력이 가장 낮은 아군 1명이 2명 이상을 공격할 때 피해량 +10%  NaN
# 01I005  최대 체력이 가장 낮은 아군 1명이 적에게 진동 폭발 시 입히는 흐트러짐 손상 4 ...  NaN
# ...                                                   ...  ...
# 12I005            속도가 가장 낮은 아군 1명이 진동이 있는 대상에게 부여하는 파열 +1  NaN
# 12I006  최대 체력이 가장 높은 아군 1명이 2개 이상의 스킬의 타겟이 되었다면 방어 레벨 ...  NaN
# 12I007  호흡이 가장 높은 아군 1명 적 처치 시 다음 턴에 관통 피해량 증가 1 얻음 (턴...  NaN
# 12I008  속도가 가장 낮은 아군 1명 출혈이 10 이상 부여된 적에게 공격 적중 시 다음 턴...  NaN
# 12I009  전투 시작 시 정신력이 가장 낮은 아군 1명 정신력 7 감소, 우울 피해량 증가 1 얻음  NaN
#
# [112 rows x 68 columns]

# %%
identity.to_excel("../data/id4.xlsx")
ego.to_excel("../data/ego4.xlsx")

# %%
identity = identity.loc[:,["sinner","identity"]]
ego = ego.loc[:,["sinner","ego"]]

# %%
identity["Lv"] = 45
identity["uptie"] = 3
ego["uptie"] = 3

# %%
pd.concat([identity,ego]).to_excel("../data/list.xlsx")

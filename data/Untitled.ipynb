# %%
import pandas as pd

# %%
data = pd.read_excel('인격.xlsx').set_index('id')
data
# Out:
#          수감자            인격   등급   속도  체력 계수  체력 상수       공격력  방어력   분노   색욕  \
# id
# 01I003    이상         검계 살수  ∅∅∅  3~7   2.28   66.0  5.000000   -4  2.0  NaN
# 01I004    이상  개화 E.G.O::동백  ∅∅∅  3~7   2.28   66.0  3.833333   -4  NaN  NaN
# 01I006    이상  W사 3등급 정리 요원  ∅∅∅  3~7   2.73   79.0  3.333333   -2  NaN  NaN
# 01I009    이상   약지 점묘파 스튜던트  ∅∅∅  3~7   2.40   70.0  3.000000   -2  NaN  2.0
# 01I002    이상   남부 세븐 협회 6과   ∅∅  5~8   2.82   82.0  0.000000    2  NaN  NaN
# ...      ...           ...  ...  ...    ...    ...       ...  ...  ...  ...
# 12I002  그레고르   남부 리우 협회 6과   ∅∅  3~7   2.17   63.0  5.000000   -4  3.0  2.0
# 12I004  그레고르     료.고.파. 조수   ∅∅  3~7   2.70   76.0  1.000000    0  NaN  3.0
# 12I005  그레고르  장미스패너 공방 해결사   ∅∅  4~6   2.39   69.0  1.000000   -2  NaN  NaN
# 12I008  그레고르       흑운회 부조장   ∅∅  4~6   2.60   76.0  1.500000    1  NaN  2.0
# 12I001  그레고르       LCB 수감자    ∅  3~7   2.48   72.0 -1.000000    0  NaN  NaN
#
# ...
